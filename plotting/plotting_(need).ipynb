# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# ## 1 A simple plot

# %% [markdown]
# ### 1.1 Let’s look at some code.

# %%
from matplotlib import pyplot as plt

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, color='red', linestyle='dashed', label='Y values') # define x and y variables and aesthetic stuff 
plt.xlabel('x-values') # give x-axis a name of x-values
plt.ylabel('y-values') # give y-axis a name of y-values
plt.title('X vs Y') # giving the graph a title
plt.grid(alpha=.25) # grid at the back and the transparency of the grid lines
plt.legend(loc='upper left') # insert legend and where it is located 
plt.show() # did not change anything

# %% [markdown]
# ### 1.2 Adding another plot

# %%
plt.plot(x, y_2, color='blue', label='Y2 values') # plots it separately

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Lets start plotting
plt.plot(x, y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(x, y_2, color='blue', label='Y2 values')                          # inserted here 
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 1.3 Yet another plot but with error bars

# %%
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75                 # must define the error before plotting 


plt.plot(x, y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(x, y_2, color='blue', label='Y2 values')
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,      # insert error bar function here. note you are plotting y3 with error
             color='green', label='Y3 with errors')   # not each line's error 
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 1.4 Experiment, Experiment, Experiment

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, color='pink', linestyle='dashed', label='Y values')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title( 'X vs Y', color ='orange') # must use american english for color spelling 
plt.grid(alpha=1.0) # alpha affects transparency 
plt.legend(loc='lower left') # change location need to use left, right, centre, lower, upper, if u dont specify loc then legend wont appear
plt.show()

# %% [markdown]
# ### 1.5 Better with NumPy

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(np_x, np_y_2, color='blue', label='Y2 values')
plt.show()

# %% [markdown]
# ### 1.6 Adding mathematical functions

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dashed', label='x^2')
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('X graphs')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 1.7 We need another axis!

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dashed', label='x^2')
plt.legend(loc='lower left')

plt.twinx()                                         # This creates a new y-axis for the plot that comes after
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.legend(loc='lower right')

plt.show()

# %%
x = np.linspace(0, 6, 100) # change x values to this range instead. linspace returns values with evenly spaced numbers over a
x2 = x**2 # specified interval. syntax is (start,stop, no. of samples)
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dashed', label='x^2')
plt.legend(loc='lower left')

plt.twinx()                                         # This creates a new y-axis for the plot that comes after
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# ### 1.8 Saving to disc

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dashed', label='x^2')
plt.legend(loc='lower left')

# This creates a new y-axis for the plot that comes after
plt.twinx()
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.legend(loc='lower right')

plt.savefig('simple-plot.png', dpi=150) # saved in directory plotting

# %% [markdown]
# ## 2 A real example: Global Warming

# %% [markdown]
# ### 2.1 Plotting data from files

# %%
data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)
date = data[:, 0] # select all rows first column 
plt.style.use('fivethirtyeight')
anomaly = data[:, -1] # all rows last column 
plt.plot(date, anomaly, alpha=.5)
plt.ylim([-8, 8])
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')

# %% [markdown]
# ### 2.2 xkcd!

# %% [markdown]
# ## Exercise 1 :  Fill in the blanks

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5]
y = [0, 4, 8, 12, 16, 20]
y_err = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
x_err = .25

plt.style.use('default')
plt.errorbar(x, y, xerr= x_err, yerr= y_err,
             color= 'black', linestyle= 'solid',
             marker='o', markerfacecolor= 'yellow',
             ecolor= 'black',capsize=5,
             label= 'Y values with error')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc = 'lower right')
#save_file_figure(plt, argv)                  # Hide
plt.show(block=False)

# %%
x = np.linspace(0, 50, 100)
y= np.exp(-x/10) * np.sin(x)
plt.ylim([-1, 1])
plt.style.use('default')
plt.plot(x,y)
plt.xlabel('x', fontdict={'fontsize': 15, 'color': 'darkblue'})
plt.ylabel('y',fontdict={'fontsize': 15, 'color': 'darkblue'})
plt.title('Graph of y = e^(-x/10)sin(x)',fontdict={'fontsize': 20})
plt.grid(alpha=.25)
plt.show()
